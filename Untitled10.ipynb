# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielSCS10565/Projeto-Ic/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ações escolhidas

# %% [markdown]
# Foram escolhidas 4 ações; Embraer, Ambev, Vale e TSM . Os dados obtidos entre  (01/01/22)  e  (01/04/22)  para podermos avaliar o comportamento dessas empresas frente a gerra Russo-Ukrainian e fazer modelos que espelhe esse cenário para essas empresas.

# %% [markdown]
# *Embraer*
#
# A Embraer é um conglomerado transnacional brasileiro, fabricante de aviões comerciais, executivos, agrícolas e militares, peças aeroespaciais, serviços e suporte na área. A empresa tem sede no município de São José dos Campos, interior do estado de São Paulo, e possui diversas unidades no Brasil e no exterior, inclusive joint ventures na China e em Portugal.
#
# A Embraer tornou-se a terceira maior fabricante de jatos comerciais do mundo e líder absoluta no segmento de até 130 assentos. Para atender demandas globais, estabeleceu unidades industriais, escritórios e centros de distribuição de peças e serviços nas Américas, África, Ásia e Europa.
#
# Sua receita líquida em 2016, foi de 21,4 bilhões de reais (6,1 bilhões de dólares). Em 2018, ocupa a terceira posição mundial no setor, abaixo da Airbus e da Boeing. Em 2012, foi a empresa que mais cresceu, entre as maiores exportadoras brasileiras (17,6% em relação a 2011).<https://pt.wikipedia.org/wiki/Embraer>
#
# Ação da Embraer no perído de $(01/01/22)$ e $(01/04/22)$
# dados obtidos no site <https://br.financas.yahoo.com>,

# %% [markdown]
# *Ambev*
#
# Ambev é uma empresa brasileira fabricante de bebidas. Pertencente ao grupo Anheuser-Busch InBev é a maior fabricante de cervejas do mundo, controla cerca de 69% do mercado brasileiro de cerveja e a 14ª maior empresa do país em receita líquida e sendo fabricante de refrigerantes, energéticos, sucos, chás e água.
#
# Oriunda da fusão entre as então concorrentes Companhia Antarctica Paulista e a Companhia Cervejaria Brahma, do Rio de Janeiro em 1999, atualmente possui mais de 30 cervejarias, maltarias, fábricas de refrigerante, rótulos, rolha e vidro, além de seis centros de excelência espalhados pelo Brasil. É conhecida pela produção de mais de 25 rótulos de cervejas pilsens, como Skol, Brahma e Budweiser e cerca de 50 do tipo ale.
#
# <https://pt.wikipedia.org/wiki/AMBEV>
#
# Ação da Ambev no perído de  $(01/01/22)$  e  $(01/04/22)$  dados obtidos no site https://br.financas.yahoo.com,

# %% [markdown]
# *Taiwan Semiconductor Manufacturing Company*
#
# Taiwan Semiconductor Manufacturing Company é uma empresa multinacional taiwanesa de contratos de fabricação de semicondutores. É uma das maiores empresas de Taiwan, mais valiosa companhia de semicondutores e a maior fábrica independente de semicondutores do mundo, o qual a sede e as operações principais localizam-se no Hsinchu Science Park em Hsinchu, Taiwan. TSMC é a primeira fabrica a produzir chips de 7 e 5 nanômetros, posteriormente aplicado no microprocessador Apple A14, o primeiro a comercializar a tecnologia de litografia Extreme Ultraviolet (EUV) em grandes volumes.
#
# Em 2022, foi considerada uma das maiores empresas de tecnologia do mundo.
#
# <https://pt.wikipedia.org/wiki/TSMC>
#
# Ação da TSM no perído de  $(01/01/22)$  e  $(01/04/22)$  dados obtidos no site https://br.financas.yahoo.com,

# %% [markdown]
# *Vale*
#
# Vale S.A. é uma mineradora multinacional brasileira e uma das maiores operadoras de logística do país. É uma das maiores empresas de mineração do mundo e também a maior produtora de minério de ferro, de pelotas e de níquel.A empresa também produz manganês, ferroliga, cobre, bauxita, potássio, caulim, alumina e alumínio. No setor de energia elétrica, a empresa participa em consórcios e atualmente opera nove usinas hidrelétricas, no Brasil, no Canadá e na Indonésia. Em 2008, a empresa chegou a ser a 33° maior do mundo (de acordo com o Financial Times de 2008) e a maior do Brasil em volume de exportações. Em 2009, a marca e o nome de fantasia da empresa deixaram de ser Companhia Vale do Rio Doce (CVRD) e passaram a ser apenas Vale S.A., nome pelo qual sempre foi conhecida nas bolsas de valores.
#
# <https://pt.wikipedia.org/wiki/Vale_S.A.>
#
# Ação da Vale no perído de  $(01/01/22)$  e  $(01/04/22)$  dados obtidos no site https://br.financas.yahoo.com,

# %% [markdown]
# # Questão 1

# %% [markdown]
# #### Letra A
#
# Calcule o valor médio m dos jumps e seu desvio-padrão. Note que estes valores
# médios são relativos a um dia pois a série temporal dos valores da ação é de cada
# dia.

# %% [markdown]
# Considere a taxa Selic em $12.24_{a.a}$

# %% [markdown]
# *Embraer*
#
# A média($\hat{m}_{dia}$) dos jumps é $0.9926$ e o desvio padrão($\hat{\sigma}_{dia}$) é $0.03242$
#
# *Ambev*
#
# A média($\hat{m}_{dia}$) dos jumps é $0.99994$ e o desvio padrão($\hat{\sigma}_{dia}$) é $0.017037$
#
# *Vale*
#
# A média($\hat{m}_{dia}$) dos jumps é $1.003782$ e o desvio padrão(($\hat{\sigma}_{dia}$)) é $0.0324176$
#
# *TMS*
#
# A média($\hat{m}_{dia}$) dos jumps é $0.997944$ e o desvio padrão($\hat{\sigma}_{dia}$) é $0.0278191$

# %% [markdown]
# #### Letra B
#
# (b) Defina o crescimento médio ti por t0 = s0 e ti+1 = m·ti, m o valor médio dos jumps do item anterior. Plot no mesmo gráco log si e log ti, sendo que este último é uma reta (Qual seu coeciente angular?). Observe que na escala de log de valores podemos enxergar os saltos médios de cada ativo através do coeciente angular da reta que aproxima o log do valor do ativo ao longo do tempo.

# %% [markdown]
# Para estimar o crescimento médio, podemos fazer $t_{i+1}=\hat{m}t_i \text{ e } t_0=s_0$
#
# Para cada $t_n^*=log(t_n) = log(s_0)+nlog(m)$

# %% [markdown]
# ![regre letra b.png](data:image/png;base64,...)

# %% [markdown]
# O coeficinete angular 0.7184809458604796 e a média dos jumps é 0.9926891995416178

# %% [markdown]
# ![regre letra b 2.png](data:image/png;base64,...)

# %% [markdown]
# O coeficinete angular da reta é 0.014653144728617146 e a média dos jumps é 0.9999392517634418

# %% [markdown]
# ![regre letra b 3.png](data:image/png;base64,...)

# %% [markdown]
# O coeficinete angular da reta é 0.7723640965054969 e a média dos jumps é 0.9926891995416178

# %% [markdown]
# ![regra letra b 4.png](data:image/png;base64,...)

# %% [markdown]
# O coeficinete angular da reta é 0.7723640965054969 e a média dos jumps é 0.9926891995416178

# %% [markdown]
# Note que estimamos os valores $S_i = e^X$ pela média dos saltos que é $t_i=e^Y$, o que nos dá o salto médio(uma aproximação)

# %% [markdown]
# #### Letra C
#
# (c) Baseado no valor médio e desvio-padrão dos jumps calculado no primeiro item, simule e plote 5 caminhos para o valor da ação durante o mesmo período (3 ou 4 meses) da série temporal. Deixe a série original no mesmo gráco em outra cor.

# %% [markdown]
# ![newplot.png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (1).png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (2).png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (3).png](data:image/png;base64,...)

# %% [markdown]
# Simulações para cada "dia" de abertura das ações, podemos ver que dentre as cinco simulações para cada ação a série real acaba ficando entre as simulações
#
# Conseguimos ver que o método JR simula bem o comportamento das ações reais.
#
# Note que nossas ações não tiveram uma queda, ou um comportamento muito drástico em relação a guerra RussoUcraniana.

# %% [markdown]
# #### Letra D
# (d) Mude a escala temporal para ∆t = 1/10 (ao invés do ∆t = 1, um dia por interação) e utilize a teoria para recalibrar o modelo (determinar os parâmetros). Calcule outros 5 caminhos nesta escala e novamente plote o caminho original em outra cor no mesmo gráco.

# %% [markdown]
# ![newplot (4).png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (5).png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (6).png](data:image/png;base64,...)

# %% [markdown]
# ![newplot (7).png](data:image/png;base64,...)

# %% [markdown]
# Ao diminuir o periodo de simulação, passar a fazer "10 vezes ao dia", podemos ver que o comportamento das series com menor escala tem uma variação menor do que com escala referente a série real
